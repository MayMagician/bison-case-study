# %%
import pandas as pd
df = pd.read_csv("mirrorPublications_featured_final.csv")

#codifico topics in one-hot encoding
one_hot_encoded_topics = pd.get_dummies(df['topic'], prefix='topic')
#trasformo i valori True e False in 0 e 1
one_hot_encoded_topics = one_hot_encoded_topics.astype(int)
#concatenazione i risultati con il df originale
df = pd.concat([df, one_hot_encoded_topics], axis=1)

df
# Out:
#                                              Writing NFT  \
# 0      https://opensea.io/assets/optimism/0x96c200ec4...
# 1      https://opensea.io/assets/optimism/0x7988434e1...
# 2      https://opensea.io/assets/optimism/0x093312465...
# 3      https://opensea.io/assets/optimism/0x901c2436d...
# 4      https://opensea.io/assets/optimism/0xe53f95be1...
# ...                                                  ...
# 26874  https://opensea.io/assets/optimism/0xe6aa6aaf3...
# 26875  https://opensea.io/assets/optimism/0xe82941552...
# 26876  https://opensea.io/assets/optimism/0x0eedbed03...
# 26877  https://opensea.io/assets/optimism/0x440f392c7...
# 26878  https://opensea.io/assets/optimism/0xb809cd58e...
#
#                                          Author Homepage  Total Sold(ETH)  \
# 0      https://mirror.xyz/0xe822ecac55a3a20bb4b24cdd8...           73.830
# 1      https://mirror.xyz/0xe822ecac55a3a20bb4b24cdd8...           52.080
# ...

# %%
df.loc[:, 'Price(ETH)'] = df['Price(ETH)'].replace(0, 0.0001)
df.loc[:, 'Success'] = (df['Total Sold Numbers'] * df['Price(ETH)']) / (df['Total Buyers'] + 1)
df
# Out:
#                                              Writing NFT  \
# 0      https://opensea.io/assets/optimism/0x96c200ec4...
# 1      https://opensea.io/assets/optimism/0x7988434e1...
# 2      https://opensea.io/assets/optimism/0x093312465...
# 3      https://opensea.io/assets/optimism/0x901c2436d...
# 4      https://opensea.io/assets/optimism/0xe53f95be1...
# ...                                                  ...
# 26874  https://opensea.io/assets/optimism/0xe6aa6aaf3...
# 26875  https://opensea.io/assets/optimism/0xe82941552...
# 26876  https://opensea.io/assets/optimism/0x0eedbed03...
# 26877  https://opensea.io/assets/optimism/0x440f392c7...
# 26878  https://opensea.io/assets/optimism/0xb809cd58e...
#
#                                          Author Homepage  Total Sold(ETH)  \
# 0      https://mirror.xyz/0xe822ecac55a3a20bb4b24cdd8...           73.830
# 1      https://mirror.xyz/0xe822ecac55a3a20bb4b24cdd8...           52.080
# ...

# %%
import matplotlib.pyplot as plt

# Visualizziamo la distribuzione della colonna "Success"
plt.figure(figsize=(10, 6))
df['Success'].hist(bins=50, color='skyblue', edgecolor='black')
plt.title("Distribuzione della colonna 'Success'", fontsize=14)
plt.xlabel("Success", fontsize=12)
plt.ylabel("Frequenza", fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
import numpy as np

# Calcolo la mediana o altra statistica
threshold = df['Success'].median()  # Soglia basata sulla mediana

# Creazione della colonna SuccessBinary
df['SuccessBinary'] = np.where(df['Success'] >= threshold, 1, 0)

# Visualizziamo la distribuzione delle due classi
df['SuccessBinary'].value_counts().plot(kind='bar', color=['skyblue', 'orange'], edgecolor='black')
plt.title("Distribuzione di SuccessBinary")
plt.xlabel("Classi (0 = Not Success, 1 = Success)")
plt.ylabel("Frequenza")
plt.xticks([0, 1], labels=["Not Success", "Success"], rotation=0)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Calcola la distribuzione della colonna 'SuccessBinary'
counts = df['SuccessBinary'].value_counts()

# Visualizza la distribuzione con un countplot
plt.figure(figsize=(8, 6))
ax = sns.countplot(data=df, x='SuccessBinary')

# Aggiungi i numeri sopra ogni barra
for p in ax.patches:
    ax.annotate(f'{int(p.get_height())}', 
                (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha='center', va='bottom')

# Aggiungi titoli e etichette
plt.title('Distribuzione della colonna SuccessBinary')
plt.xlabel('SuccessBinary')
plt.ylabel('Frequenza')

# Mostra il grafico
plt.show()

# Mostra i numeri della distribuzione
print("Distribuzione dei valori di 'SuccessBinary':")
counts
# Out:
# Distribuzione dei valori di 'SuccessBinary':
# SuccessBinary
# 1    13710
# 0    13169
# Name: count, dtype: int64

# %%
from sklearn.impute import SimpleImputer
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# Esempio: Preprocessing dei dati
# Separa il tuo dataframe in variabili di input (X) e target (y)
X = df.drop(columns=['Writing NFT', 'Author Homepage', 'Total Sold(ETH)', 'Total Sold Numbers', 'Total Buyers',
    'Price(ETH)', 'nft_address', 'collection', 'fees', 'created_date', 'link', 'digest', 'body', 'timestamp', 'title', 'cleaned_text', 
    'cleaned_body', 'cleaned_title', 'processed_cleaned_text', 'weekday', 'language',
    'cleaned_text_tokenized', 'cleaned_text_lemmatized', 'cleaned_text_POS', "topic",
    'transaction_id', 'Success', 'SuccessBinary'])
y = df['SuccessBinary']

# Suddividi in train e test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)

# Applica imputazione per i valori NaN
imputer = SimpleImputer(strategy='mean')  # Puoi cambiare la strategia (media, mediana, costante, ecc.)
X_train_imputed = imputer.fit_transform(X_train)
X_test_imputed = imputer.transform(X_test)

# Standardizza i dati
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train_imputed)
X_test_scaled = scaler.transform(X_test_imputed)

# Allena il modello Gradient Boosting
gb_model = GradientBoostingClassifier(
    learning_rate=0.1,
    max_depth=5,
    n_estimators=100,
    random_state=42
)

gb_model.fit(X_train_scaled, y_train)

# Previsioni e valutazione
y_pred = gb_model.predict(X_test_scaled)

from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.71      0.63      0.67      2634
#            1       0.68      0.75      0.71      2742
#
#     accuracy                           0.69      5376
#    macro avg       0.69      0.69      0.69      5376
# weighted avg       0.69      0.69      0.69      5376

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import classification_report
import numpy as np

# Creazione del modello MLP (Multi-Layer Perceptron)
model = Sequential()

# Input layer
model.add(Dense(128, activation='relu', input_dim=X_train_scaled.shape[1]))

# Hidden layers
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.3))  # Dropout per prevenire overfitting
model.add(Dense(32, activation='relu'))

# Output layer
model.add(Dense(1, activation='sigmoid'))  # Sigmoid per classificazione binaria

# Compilazione del modello
model.compile(optimizer=Adam(learning_rate=0.001), loss='binary_crossentropy', metrics=['accuracy'])

# Addestramento del modello
history = model.fit(
    X_train_scaled,
    y_train,
    epochs=50,  # Puoi aggiustare il numero di epoche
    batch_size=32,
    validation_split=0.2,  # Usa il 20% dei dati di training per la validazione
    verbose=1
)

# Valutazione sul test set
y_pred_proba = model.predict(X_test_scaled)
y_pred = (y_pred_proba > 0.5).astype(int)  # Converte probabilità in 0/1

# Stampa il report di classificazione
print(classification_report(y_test, y_pred))
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# Epoch 1/100
# 538/538 [==============================] - 0s 509us/step - loss: 0.6502 - accuracy: 0.6236 - val_loss: 0.6402 - val_accuracy: 0.6245
# Epoch 2/100
# 538/538 [==============================] - 0s 424us/step - loss: 0.6308 - accuracy: 0.6471 - val_loss: 0.6314 - val_accuracy: 0.6454
# Epoch 3/100
# 538/538 [==============================] - 0s 424us/step - loss: 0.6221 - accuracy: 0.6522 - val_loss: 0.6232 - val_accuracy: 0.6498
# Epoch 4/100
# 538/538 [==============================] - 0s 422us/step - loss: 0.6156 - accuracy: 0.6596 - val_loss: 0.6232 - val_accuracy: 0.6473
# Epoch 5/100
# 538/538 [==============================] - 0s 423us/step - loss: 0.6115 - accuracy: 0.6664 - val_loss: 0.6201 - val_accuracy: 0.6517
# Epoch 6/100
# ...

# %%
from keras_tuner import RandomSearch
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam

# Funzione per costruire il modello
def build_model(hp):
    model = Sequential()
    # Primo livello nascosto
    model.add(Dense(
        units=hp.Int('units_layer1', min_value=32, max_value=256, step=32),
        activation='relu',
        input_dim=X_train_scaled.shape[1]
    ))
    # Secondo livello nascosto
    model.add(Dense(
        units=hp.Int('units_layer2', min_value=32, max_value=256, step=32),
        activation='relu'
    ))
    model.add(Dropout(hp.Float('dropout_rate', min_value=0.1, max_value=0.5, step=0.1)))
    # Livello di output
    model.add(Dense(1, activation='sigmoid'))

    # Compilazione del modello
    model.compile(
        optimizer=Adam(learning_rate=hp.Choice('learning_rate', values=[1e-2, 1e-3, 1e-4])),
        loss='binary_crossentropy',
        metrics=['accuracy']
    )
    return model

# Configurazione della ricerca random
tuner = RandomSearch(
    build_model,
    objective='val_accuracy',
    max_trials=10,  # Numero massimo di combinazioni da testare
    executions_per_trial=1,
    directory='my_dir',
    project_name='tuner_nn'
)

# Avvio della ricerca
tuner.search(X_train_scaled, y_train, epochs=50, validation_split=0.2, verbose=1)

# Ottieni i migliori iperparametri
best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]
print(f"Migliori iperparametri trovati:")
print(f" - Unità nel primo livello: {best_hps.get('units_layer1')}")
print(f" - Unità nel secondo livello: {best_hps.get('units_layer2')}")
print(f" - Tasso di dropout: {best_hps.get('dropout_rate')}")
print(f" - Learning rate: {best_hps.get('learning_rate')}")

# Costruisci il miglior modello e addestralo
best_model = tuner.hypermodel.build(best_hps)
history = best_model.fit(X_train_scaled, y_train, epochs=50, validation_split=0.2, batch_size=32, verbose=1)
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# Trial 10 Complete [00h 00m 14s]
# val_accuracy: 0.6689141988754272
#
# Best val_accuracy So Far: 0.6721692681312561
# Total elapsed time: 00h 02m 07s
# Migliori iperparametri trovati:
#  - Unità nel primo livello: 160
#  - Unità nel secondo livello: 128
#  - Tasso di dropout: 0.30000000000000004
#  - Learning rate: 0.001
# Epoch 1/50
# 538/538 [==============================] - 0s 547us/step - loss: 0.6473 - accuracy: 0.6261 - val_loss: 0.6325 - val_accuracy: 0.6431
# Epoch 2/50
# 538/538 [==============================] - 0s 472us/step - loss: 0.6293 - accuracy: 0.6474 - val_loss: 0.6299 - val_accuracy: 0.6433
# Epoch 3/50
# 538/538 [==============================] - 0s 471us/step - loss: 0.6190 - accuracy: 0.6614 - val_loss: 0.6167 - val_accuracy: 0.6561
# Epoch 4/50
# ...

# %%
from keras_tuner import RandomSearch
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import classification_report
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.regularizers import l2

# Funzione per costruire il modello
def build_model(hp):
    model = Sequential()
    # Primo livello nascosto
    model.add(Dense(
        units=hp.Int('units_layer1', min_value=32, max_value=256, step=32),
        activation='relu',
        input_dim=X_train_scaled.shape[1]
    ))
    # Secondo livello nascosto
    model.add(Dense(
        units=hp.Int('units_layer2', min_value=32, max_value=256, step=32),
        activation='relu'
    ))
    model.add(Dropout(hp.Float('dropout_rate', min_value=0.1, max_value=0.5, step=0.1)))
    # Livello di output
    model.add(Dense(1, activation='sigmoid'))

    # Compilazione del modello
    model.compile(
        optimizer=Adam(learning_rate=hp.Choice('learning_rate', values=[1e-2, 1e-3, 1e-4])),
        loss='binary_crossentropy',
        metrics=['accuracy']
    )
    return model

# Configurazione della ricerca random
tuner = RandomSearch(
    build_model,
    objective='val_accuracy',
    max_trials=10,  # Numero massimo di combinazioni da testare
    executions_per_trial=1,
    directory='my_dir',
    project_name='tuner_nn'
)

# Avvio della ricerca
tuner.search(X_train_scaled, y_train, epochs=50, validation_split=0.2, verbose=1)

# Ottieni i migliori iperparametri
best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]
print(f"Migliori iperparametri trovati:")
print(f" - Unità nel primo livello: {best_hps.get('units_layer1')}")
print(f" - Unità nel secondo livello: {best_hps.get('units_layer2')}")
print(f" - Tasso di dropout: {best_hps.get('dropout_rate')}")
print(f" - Learning rate: {best_hps.get('learning_rate')}")

# Costruisci il miglior modello e addestralo
best_model = tuner.hypermodel.build(best_hps)
history = best_model.fit(X_train_scaled, y_train, epochs=50, validation_split=0.2, batch_size=32, verbose=1)

# Valutazione sul test set
y_pred_proba = best_model.predict(X_test_scaled)
y_pred = (y_pred_proba > 0.5).astype(int)

# Stampa il classification report
print("Classification Report:")
print(classification_report(y_test, y_pred))

# Visualizzazione della cronologia dell'addestramento
# Accuratezza
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Train vs Validation Accuracy')
plt.show()

# Perdita
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.title('Train vs Validation Loss')
plt.show()
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# Reloading Tuner from my_dir/tuner_nn/tuner0.json
# Migliori iperparametri trovati:
#  - Unità nel primo livello: 160
#  - Unità nel secondo livello: 128
#  - Tasso di dropout: 0.30000000000000004
#  - Learning rate: 0.001
# Epoch 1/50
# 538/538 [==============================] - 0s 544us/step - loss: 0.6491 - accuracy: 0.6216 - val_loss: 0.6443 - val_accuracy: 0.6261
# Epoch 2/50
# 538/538 [==============================] - 0s 467us/step - loss: 0.6268 - accuracy: 0.6521 - val_loss: 0.6285 - val_accuracy: 0.6454
# Epoch 3/50
# 538/538 [==============================] - 0s 505us/step - loss: 0.6200 - accuracy: 0.6607 - val_loss: 0.6192 - val_accuracy: 0.6510
# Epoch 4/50
# ...

# %%
#riprovo con regolarizzazione L2 ed early stopping per evitare overfitting

from keras_tuner import RandomSearch
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import classification_report
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import EarlyStopping

# Funzione per costruire il modello con regolarizzazione L2 e Early Stopping
def build_model(hp):
    model = Sequential()
    # Primo livello nascosto con regolarizzazione L2
    model.add(Dense(
        units=hp.Int('units_layer1', min_value=32, max_value=256, step=32),
        activation='relu',
        input_dim=X_train_scaled.shape[1],
        kernel_regularizer=l2(hp.Float('l2_rate', min_value=1e-5, max_value=1e-2, sampling='LOG')) # Regolarizzazione L2
    ))
    model.add(Dropout(hp.Float('dropout_rate1', min_value=0.1, max_value=0.5, step=0.1))) # Dropout dopo il primo livello

    # Secondo livello nascosto con regolarizzazione L2
    model.add(Dense(
        units=hp.Int('units_layer2', min_value=32, max_value=256, step=32),
        activation='relu',
        kernel_regularizer=l2(hp.Float('l2_rate', min_value=1e-5, max_value=1e-2, sampling='LOG')) # Regolarizzazione L2
    ))
    model.add(Dropout(hp.Float('dropout_rate2', min_value=0.1, max_value=0.5, step=0.1))) # Dropout dopo il secondo livello

    # Livello di output
    model.add(Dense(1, activation='sigmoid'))

    # Compilazione del modello
    model.compile(
        optimizer=Adam(learning_rate=hp.Choice('learning_rate', values=[1e-2, 1e-3, 1e-4])),
        loss='binary_crossentropy',
        metrics=['accuracy']
    )
    return model

# Configurazione della ricerca random
tuner = RandomSearch(
    build_model,
    objective='val_accuracy',
    max_trials=20,  # Aumenta il numero di tentativi
    executions_per_trial=1,
    directory='my_dir',
    project_name='tuner_nn'
)

# Early Stopping
early_stopping = EarlyStopping(
    monitor='val_loss',  # Monitora la loss di validazione
    patience=10,         # Numero di epoch senza miglioramento prima di fermarsi
    restore_best_weights=True # Ripristina i pesi del modello con la miglior performance
)

# Avvio della ricerca con Early Stopping
tuner.search(X_train_scaled, y_train, epochs=100, validation_split=0.2, verbose=1, callbacks=[early_stopping]) # Aggiunto EarlyStopping


# Ottieni i migliori iperparametri
best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]
print(f"Migliori iperparametri trovati:")
print(f" - Unità nel primo livello: {best_hps.get('units_layer1')}")
print(f" - Unità nel secondo livello: {best_hps.get('units_layer2')}")
print(f" - Tasso di dropout 1: {best_hps.get('dropout_rate1')}")
print(f" - Tasso di dropout 2: {best_hps.get('dropout_rate2')}")
print(f" - L2 rate: {best_hps.get('l2_rate')}") # Aggiunto L2 rate
print(f" - Learning rate: {best_hps.get('learning_rate')}")

# Costruisci il miglior modello e addestralo (con Early Stopping)
best_model = tuner.hypermodel.build(best_hps)
history = best_model.fit(X_train_scaled, y_train, epochs=100, validation_split=0.2, batch_size=32, verbose=1, callbacks=[early_stopping]) # Aggiunto EarlyStopping

# Valutazione sul test set
y_pred_proba = best_model.predict(X_test_scaled)
y_pred = (y_pred_proba > 0.5).astype(int)

# Stampa il classification report
print("Classification Report:")
print(classification_report(y_test, y_pred))

# Visualizzazione della cronologia dell'addestramento
# Accuratezza
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Train vs Validation Accuracy')
plt.show()

# Perdita
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.title('Train vs Validation Loss')
plt.show()
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# Trial 20 Complete [00h 00m 34s]
# val_accuracy: 0.675424337387085
#
# Best val_accuracy So Far: 0.675424337387085
# Total elapsed time: 00h 34m 13s
# Migliori iperparametri trovati:
#  - Unità nel primo livello: 224
#  - Unità nel secondo livello: 160
#  - Tasso di dropout 1: 0.1
#  - Tasso di dropout 2: 0.5
#  - L2 rate: 0.0002708552306012994
#  - Learning rate: 0.0001
# Epoch 1/100
# 538/538 [==============================] - 1s 702us/step - loss: 0.7377 - accuracy: 0.5912 - val_loss: 0.7083 - val_accuracy: 0.6343
# Epoch 2/100
# 538/538 [==============================] - 0s 624us/step - loss: 0.7158 - accuracy: 0.6219 - val_loss: 0.6993 - val_accuracy: 0.6419
# Epoch 3/100
# ...

# %%
#modello coi parametri migliori già trovati, solo da copiare e incollare per il futuro

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import EarlyStopping

def build_and_train_best_model(X_train_scaled, y_train, X_test_scaled, y_test):
    # Parametri ottimizzati
    units_layer1 = 224
    units_layer2 = 160
    dropout_rate1 = 0.1
    dropout_rate2 = 0.5
    l2_rate = 0.0002708552306012994
    learning_rate = 0.0001

    # Costruzione del modello
    model = Sequential()
    model.add(Dense(
        units=units_layer1,
        activation='relu',
        input_dim=X_train_scaled.shape[1],
        kernel_regularizer=l2(l2_rate)  # Regolarizzazione L2
    ))
    model.add(Dropout(dropout_rate1))  # Dropout dopo il primo livello

    model.add(Dense(
        units=units_layer2,
        activation='relu',
        kernel_regularizer=l2(l2_rate)  # Regolarizzazione L2
    ))
    model.add(Dropout(dropout_rate2))  # Dropout dopo il secondo livello

    model.add(Dense(1, activation='sigmoid'))  # Livello di output

    # Compilazione del modello
    model.compile(
        optimizer=Adam(learning_rate=learning_rate),
        loss='binary_crossentropy',
        metrics=['accuracy']
    )

    # Early Stopping
    early_stopping = EarlyStopping(
        monitor='val_loss',
        patience=10,
        restore_best_weights=True
    )

    # Addestramento del modello
    history = model.fit(
        X_train_scaled, y_train,
        epochs=100,
        validation_split=0.2,
        batch_size=32,
        verbose=1,
        callbacks=[early_stopping]
    )

    # Valutazione sul test set
    y_pred_proba = model.predict(X_test_scaled)
    y_pred = (y_pred_proba > 0.5).astype(int)

    # Stampa il classification report
    from sklearn.metrics import classification_report
    print("Classification Report:")
    print(classification_report(y_test, y_pred))

    # Visualizzazione della cronologia dell'addestramento
    import matplotlib.pyplot as plt

    # Accuratezza
    plt.plot(history.history['accuracy'], label='Train Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.title('Train vs Validation Accuracy')
    plt.show()

    # Perdita
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.title('Train vs Validation Loss')
    plt.show()

    # Restituisce il modello addestrato
    return model

# Esegui la funzione
model = build_and_train_best_model(X_train_scaled, y_train, X_test_scaled, y_test)
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# Epoch 1/100
# 538/538 [==============================] - 1s 702us/step - loss: 0.7455 - accuracy: 0.5894 - val_loss: 0.7128 - val_accuracy: 0.6210
# Epoch 2/100
# 538/538 [==============================] - 0s 619us/step - loss: 0.7189 - accuracy: 0.6191 - val_loss: 0.7036 - val_accuracy: 0.6301
# Epoch 3/100
# 538/538 [==============================] - 0s 618us/step - loss: 0.7080 - accuracy: 0.6333 - val_loss: 0.6986 - val_accuracy: 0.6347
# Epoch 4/100
# 538/538 [==============================] - 0s 622us/step - loss: 0.7003 - accuracy: 0.6382 - val_loss: 0.6933 - val_accuracy: 0.6371
# Epoch 5/100
# 538/538 [==============================] - 0s 619us/step - loss: 0.6947 - accuracy: 0.6417 - val_loss: 0.6901 - val_accuracy: 0.6373
# Epoch 6/100
# ...

# %%
from lime.lime_tabular import LimeTabularExplainer

columns_to_exclude = ['Writing NFT', 'Author Homepage', 'Total Sold(ETH)', 'Total Sold Numbers', 'Total Buyers',
                      'Price(ETH)', 'nft_address', 'collection', 'fees', 'created_date', 'link', 'digest', 'body', 
                      'timestamp', 'title', 'cleaned_text', 'cleaned_body', 'cleaned_title', 'processed_cleaned_text', 
                      'weekday', 'language', 'cleaned_text_tokenized', 'cleaned_text_lemmatized', 
                      'cleaned_text_POS', 'topic', 'transaction_id', 'Success', 'SuccessBinary']

# Seleziona tutte le colonne tranne quelle da escludere
feature_names = [col for col in df.columns if col not in columns_to_exclude]

# Crea un explainer LIME
explainer = LimeTabularExplainer(
    training_data=X_train_scaled,
    training_labels=y_train,
    mode='classification',
    feature_names=feature_names,
    class_names=["Not success", "Success"],
    discretize_continuous=True
)

def predict_proba(X):
    prob = model.predict(X)
    return np.hstack([1 - prob, prob])

# Ora passa questa funzione a LIME
explanation = explainer.explain_instance(X_test_scaled[idx], predict_proba)

# Visualizza l'explanation
explanation.show_in_notebook(show_table=True, show_all=False)
# Out:
# 157/157 [==============================] - 0s 793us/step
# <html>
#         <meta http-equiv="content-type" content="text/html; charset=UTF8">
#         <head><script>var lime =
# /******/ (function(modules) { // webpackBootstrap
# /******/ 	// The module cache
# /******/ 	var installedModules = {};
# /******/
# /******/ 	// The require function
# /******/ 	function __webpack_require__(moduleId) {
# /******/
# /******/ 		// Check if module is in cache
# /******/ 		if(installedModules[moduleId])
# /******/ 			return installedModules[moduleId].exports;
# /******/
# /******/ 		// Create a new module (and put it into the cache)
# /******/ 		var module = installedModules[moduleId] = {
# /******/ 			exports: {},
# /******/ 			id: moduleId,
# /******/ 			loaded: false
# /******/ 		};
# /******/
# /******/ 		// Execute the module function
# /******/ 		modules[moduleId].call(module.exports, module, module.exports, __webpack_require__);
# /******/
# /******/ 		// Flag the module as loaded
# ...

# %% [markdown]
# Due appunti di chatgpt a proposito di questa spiegazione:
#
# sentences_per_paragraph: La caratteristica "sentences per paragraph" ha un effetto negativo sulla previsione (valore -0.09), quindi meno frasi per paragrafo potrebbe indicare una maggiore probabilità di "non successo".
#
# topic_T6: Web3 Launches, Rewards & Creators: Questo è un argomento (topic) derivato dal topic modeling (probabilmente LDA). Ha un impatto negativo sulla previsione, con valore -0.43.
#
# wordtypes: Un altro tipo di caratteristica testuale, che ha un effetto negativo sulla previsione.
#
# year: L'anno in cui è stato creato l'articolo ha un impatto positivo sulla previsione, con un valore di 0.14, quindi più recente è l'articolo, maggiore è la probabilità di "successo".
#
# paragraphs: Il numero di paragrafi ha un impatto positivo sulla previsione, con valore 0.52. Articoli con più paragrafi sono più probabilmente associati a un "successo".
#
# topic_T4, topic_T5: Altri argomenti (topic) del testo, che influenzano la previsione negativamente.
#
# long_words: La presenza di parole lunghe ha un effetto negativo sulla previsione (valore -0.44).
#
# GunningFogIndex: Questo indice di complessità del testo ha un effetto negativo sulla previsione (valore -0.78), suggerendo che un indice di difficoltà più alto porta a una maggiore probabilità di "non successo".
#
# words_title: La lunghezza del titolo, che ha un impatto positivo sulla previsione (valore 0.40).
